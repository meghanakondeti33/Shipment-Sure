# %%
# ============================================================
# SHIPMENTSURE
# On-Time Shipment Prediction
# ============================================================

import os
import warnings
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: scikit-learn in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: xgboost in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: joblib in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: pandas in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 4)) (3.0.5)
# Requirement already satisfied: numpy in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 5)) (2.4.6)
# Requirement already satisfied: imblearn in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (0.0)
# Requirement already satisfied: matplotlib in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 7)) (3.11.1)
# Requirement already satisfied: seaborn in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: lightgbm in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 9)) (4.7.0)
# Requirement already satisfied: catboost in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 10)) (1.2.10)
# Requirement already satisfied: streamlit in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 12)) (1.62.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->-r requirements.txt (line 1)) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2026.3)
# Requirement already satisfied: imbalanced-learn in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from imblearn->-r requirements.txt (line 6)) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: graphviz in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from catboost->-r requirements.txt (line 10)) (0.21)
# Requirement already satisfied: plotly in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from catboost->-r requirements.txt (line 10)) (6.9.0)
# Requirement already satisfied: six in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from catboost->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (8.4.2)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (0.9.3)
# Requirement already satisfied: protobuf<8,>=5.26.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (5.29.6)
# Requirement already satisfied: pyarrow!=25.0.0,<26,>=7.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (2.34.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: starlette<2,>=0.46.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (0.30.6)
# Requirement already satisfied: httptools<1,>=0.6.3 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (0.8.0)
# Requirement already satisfied: anyio<5,>=4.0.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (4.14.2)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (0.0.32)
# Requirement already satisfied: websockets<17,>=12.0.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (15.0.1)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from streamlit->-r requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (4.25.1)
# Requirement already satisfied: idna>=2.8 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=4.0.0->streamlit->-r requirements.txt (line 12)) (3.11)
# Requirement already satisfied: colorama in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 12)) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 12)) (2.6.1)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 12)) (2025.11.12)
# Requirement already satisfied: h11>=0.8 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from uvicorn<1,>=0.30.0->streamlit->-r requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.6 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cse\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit->-r requirements.txt (line 12)) (0.30.0)
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: C:\Users\CSE\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (2.2.6)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.6 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (0.1.6)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\cse\appdata\local\programs\python\python310\lib\site-packages (from imbalanced-learn) (1.5.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ============================================================
# MACHINE LEARNING IMPORTS
# ============================================================

from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    cross_val_score
)

from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder
)

from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline as SklearnPipeline

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.naive_bayes import GaussianNB

from sklearn.neighbors import KNeighborsClassifier

from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve
)

from imblearn.pipeline import Pipeline as ImbPipeline

from imblearn.over_sampling import SMOTE

from xgboost import XGBClassifier

from lightgbm import LGBMClassifier

from catboost import CatBoostClassifier

print("Machine learning libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 51
#      47 from imblearn.pipeline import Pipeline as ImbPipeline
#      49 from imblearn.over_sampling import SMOTE
# ---> 51 from xgboost import XGBClassifier
#      53 from lightgbm import LGBMClassifier
#      55 from catboost import CatBoostClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, roc_auc_score, roc_curve, auc
)

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %%
# ============================================================
# BASIC DATASET INFORMATION
# ============================================================

print("Shape:", df.shape)

print("\nFirst 5 rows:")
display(df.head())

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nDataset information:")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
# ============================================================
# BASIC DATASET INFORMATION
# ============================================================

print("Shape:", df.shape)

print("\nFirst 5 rows:")
display(df.head())

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nDataset information:")
df.info()

# %%
# ============================================================
# MISSING VALUE ANALYSIS
# ============================================================

missing_values = df.isnull().sum()

missing_df = pd.DataFrame({
    "Column": missing_values.index,
    "Missing Values": missing_values.values,
    "Percentage": (
        missing_values.values / len(df) * 100
    ).round(2)
})

display(
    missing_df[
        missing_df["Missing Values"] > 0
    ]
)

# %%
# ============================================================
# DUPLICATE ANALYSIS
# ============================================================

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)

if duplicate_count > 0:
    df = df.drop_duplicates().reset_index(drop=True)
    print("Duplicates removed.")

print("New shape:", df.shape)

# %%
# ============================================================
# TARGET VARIABLE ANALYSIS
# ============================================================

TARGET = "Reached.on.Time_Y.N"

print("Target distribution:")
print(df[TARGET].value_counts())

print("\nTarget proportions:")
print(
    df[TARGET]
    .value_counts(normalize=True)
    .round(4)
)

plt.figure(figsize=(6, 5))

sns.countplot(
    data=df,
    x=TARGET
)

plt.title("Target Variable Distribution")
plt.xlabel("Reached On Time (0 = No, 1 = Yes)")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# NUMERICAL FEATURE SUMMARY
# ============================================================

display(
    df.describe().T
)

# %%
# ============================================================
# CATEGORICAL FEATURE ANALYSIS
# ============================================================

categorical_columns = df.select_dtypes(
    include=["object"]
).columns.tolist()

print("Categorical columns:")
for column in categorical_columns:
    print(
        f"\n{column}:"
    )
    print(
        df[column].value_counts()
    )

# %%
# ============================================================
# NUMERICAL FEATURES
# ============================================================

numerical_columns = df.select_dtypes(
    include=[np.number]
).columns.tolist()

print("Numerical columns:")
print(numerical_columns)

# %%
# ============================================================
# NUMERICAL FEATURE DISTRIBUTIONS
# ============================================================

for column in numerical_columns:

    if column == TARGET:
        continue

    plt.figure(figsize=(7, 4))

    sns.histplot(
        data=df,
        x=column,
        kde=True
    )

    plt.title(f"Distribution of {column}")
    plt.tight_layout()
    plt.show()

# %%
# ============================================================
# OUTLIER ANALYSIS
# ============================================================

for column in numerical_columns:

    if column == TARGET:
        continue

    plt.figure(figsize=(7, 4))

    sns.boxplot(
        data=df,
        x=column
    )

    plt.title(f"Boxplot of {column}")
    plt.tight_layout()
    plt.show()

# %%
# ============================================================
# CATEGORICAL FEATURES VS TARGET
# ============================================================

for column in categorical_columns:

    plt.figure(figsize=(8, 5))

    sns.countplot(
        data=df,
        x=column,
        hue=TARGET
    )

    plt.title(
        f"{column} vs On-Time Delivery"
    )

    plt.xticks(rotation=30)

    plt.tight_layout()
    plt.show()

# %%
# ============================================================
# NUMERICAL FEATURES VS TARGET
# ============================================================

for column in numerical_columns:

    if column == TARGET:
        continue

    plt.figure(figsize=(7, 5))

    sns.boxplot(
        data=df,
        x=TARGET,
        y=column
    )

    plt.title(
        f"{column} vs On-Time Delivery"
    )

    plt.tight_layout()
    plt.show()

# %%
# ============================================================
# FEATURE ENGINEERING
# ============================================================

model_df = df.copy()

# Cost-to-Weight Ratio
model_df["Cost_to_Weight_Ratio"] = (
    model_df["Cost_of_the_Product"]
    /
    model_df["Weight_in_gms"].replace(0, np.nan)
)

# Replace infinite values
model_df.replace(
    [np.inf, -np.inf],
    np.nan,
    inplace=True
)

# Fill missing engineered feature
model_df["Cost_to_Weight_Ratio"] = (
    model_df["Cost_to_Weight_Ratio"]
    .fillna(
        model_df["Cost_to_Weight_Ratio"].median()
    )
)

print("Feature engineering completed.")

display(
    model_df.head()
)

# %%
# ============================================================
# CORRELATION HEATMAP
# ============================================================

numeric_df = model_df.select_dtypes(
    include=[np.number]
)

corr_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title(
    "Correlation Heatmap"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# FEATURES AND TARGET
# ============================================================

TARGET = "Reached.on.Time_Y.N"

# ID is only an identifier
X = model_df.drop(
    columns=[
        "ID",
        TARGET
    ]
)

y = model_df[TARGET]

print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nFeatures:")
print(X.columns.tolist())

print("\nTarget:")
print(y.name)

# %%
# ============================================================
# FEATURE TYPES
# ============================================================

categorical_features = X.select_dtypes(
    include=["object"]
).columns.tolist()

numerical_features = X.select_dtypes(
    include=[np.number]
).columns.tolist()

print("Categorical features:")
print(categorical_features)

print("\nNumerical features:")
print(numerical_features)

# %%
# ============================================================
# TRAIN / VALIDATION / TEST SPLIT
# ============================================================

# 80% training pool
# 20% untouched test set

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# From training pool:
# 80% actual training
# 20% validation

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full,
    y_train_full,
    test_size=0.20,
    random_state=42,
    stratify=y_train_full
)

print("Training:", X_train.shape)
print("Validation:", X_val.shape)
print("Test:", X_test.shape)

print("\nTarget distribution")

print("\nTraining:")
print(
    y_train.value_counts(normalize=True)
)

print("\nValidation:")
print(
    y_val.value_counts(normalize=True)
)

print("\nTest:")
print(
    y_test.value_counts(normalize=True)
)

# %%
# ============================================================
# PREPROCESSING PIPELINE
# ============================================================

# Numerical preprocessing
numeric_transformer = SklearnPipeline(
    steps=[
        (
            "imputer",
            SimpleImputer(
                strategy="median"
            )
        ),
        (
            "scaler",
            StandardScaler()
        )
    ]
)

# Categorical preprocessing
categorical_transformer = SklearnPipeline(
    steps=[
        (
            "imputer",
            SimpleImputer(
                strategy="most_frequent"
            )
        ),
        (
            "onehot",
            OneHotEncoder(
                handle_unknown="ignore",
                sparse_output=False
            )
        )
    ]
)

# Combine numerical + categorical processing
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            numeric_transformer,
            numerical_features
        ),
        (
            "cat",
            categorical_transformer,
            categorical_features
        )
    ]
)

print("Preprocessing pipeline created.")

# %%
# ============================================================
# MACHINE LEARNING MODELS
# ============================================================

models = {

    "Logistic Regression": LogisticRegression(
        C=0.5,
        max_iter=1000,
        random_state=42
    ),

    "Decision Tree": DecisionTreeClassifier(
        max_depth=8,
        min_samples_split=10,
        min_samples_leaf=5,
        random_state=42
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        min_samples_split=10,
        min_samples_leaf=5,
        random_state=42,
        n_jobs=-1
    ),

    "Naive Bayes": GaussianNB(),

    "KNN": KNeighborsClassifier(
        n_neighbors=9
    ),

    "SVM": SVC(
        C=0.5,
        kernel="rbf",
        probability=True,
        random_state=42
    ),

    "XGBoost": XGBClassifier(
        learning_rate=0.05,
        n_estimators=500,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=0.5,
        eval_metric="logloss",
        random_state=42
    ),

    "LightGBM": LGBMClassifier(
        learning_rate=0.05,
        n_estimators=500,
        max_depth=6,
        num_leaves=20,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=0.2,
        reg_lambda=0.5,
        random_state=42,
        verbosity=-1
    ),

    "CatBoost": CatBoostClassifier(
        iterations=500,
        learning_rate=0.05,
        depth=6,
        l2_leaf_reg=5,
        verbose=False,
        random_state=42
    )
}

print("Models defined:")
for name in models:
    print("-", name)

# %%
# ============================================================
# TRAIN ALL MODELS
# ============================================================

results = []

trained_pipelines = {}

for name, model in models.items():

    print("\n" + "=" * 70)
    print("Training:", name)
    print("=" * 70)

    # Complete pipeline:
    #
    # Raw data
    #     ↓
    # Preprocessing
    #     ↓
    # SMOTE
    #     ↓
    # Model

    pipeline = ImbPipeline(
        steps=[
            (
                "preprocessor",
                preprocessor
            ),

            (
                "smote",
                SMOTE(
                    random_state=42
                )
            ),

            (
                "model",
                model
            )
        ]
    )

    # Train
    pipeline.fit(
        X_train,
        y_train
    )

    # Validation predictions
    y_pred = pipeline.predict(
        X_val
    )

    y_prob = pipeline.predict_proba(
        X_val
    )[:, 1]

    # Metrics
    accuracy = accuracy_score(
        y_val,
        y_pred
    )

    precision = precision_score(
        y_val,
        y_pred,
        zero_division=0
    )

    recall = recall_score(
        y_val,
        y_pred,
        zero_division=0
    )

    f1 = f1_score(
        y_val,
        y_pred,
        zero_division=0
    )

    roc_auc = roc_auc_score(
        y_val,
        y_prob
    )

    # Store
    results.append({
        "Model": name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "ROC-AUC": roc_auc
    })

    trained_pipelines[name] = pipeline

    print(
        f"Accuracy : {accuracy:.4f}"
    )

    print(
        f"Precision: {precision:.4f}"
    )

    print(
        f"Recall   : {recall:.4f}"
    )

    print(
        f"F1 Score : {f1:.4f}"
    )

    print(
        f"ROC-AUC  : {roc_auc:.4f}"
    )

# %%
# ============================================================
# MODEL COMPARISON
# ============================================================

comparison_df = pd.DataFrame(
    results
)

comparison_df = comparison_df.sort_values(
    by="ROC-AUC",
    ascending=False
).reset_index(drop=True)

display(
    comparison_df.round(4)
)

# %%
# ============================================================
# ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(12, 6))

sns.barplot(
    data=comparison_df,
    x="Model",
    y="Accuracy"
)

plt.xticks(
    rotation=45,
    ha="right"
)

plt.title(
    "Model Accuracy Comparison"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(12, 6))

sns.barplot(
    data=comparison_df,
    x="Model",
    y="Accuracy"
)

plt.xticks(
    rotation=45,
    ha="right"
)

plt.title(
    "Model Accuracy Comparison"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# ROC-AUC COMPARISON
# ============================================================

plt.figure(figsize=(12, 6))

sns.barplot(
    data=comparison_df,
    x="Model",
    y="ROC-AUC"
)

plt.xticks(
    rotation=45,
    ha="right"
)

plt.title(
    "Model ROC-AUC Comparison"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# VERIFY MODEL PREDICTIONS
# ============================================================

prediction_summary = []

for name, pipeline in trained_pipelines.items():

    predictions = pipeline.predict(
        X_val
    )

    unique_values, counts = np.unique(
        predictions,
        return_counts=True
    )

    prediction_summary.append({
        "Model": name,
        "Class 0 Predictions": counts[
            list(unique_values).index(0)
        ] if 0 in unique_values else 0,

        "Class 1 Predictions": counts[
            list(unique_values).index(1)
        ] if 1 in unique_values else 0
    })

prediction_summary_df = pd.DataFrame(
    prediction_summary
)

display(
    prediction_summary_df
)

# %%
# ============================================================
# 10-FOLD STRATIFIED CROSS VALIDATION
# XGBOOST
# ============================================================

cv = StratifiedKFold(
    n_splits=10,
    shuffle=True,
    random_state=42
)

xgb_cv_pipeline = ImbPipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),

        (
            "smote",
            SMOTE(
                random_state=42
            )
        ),

        (
            "model",
            XGBClassifier(
                learning_rate=0.05,
                n_estimators=500,
                max_depth=6,
                subsample=0.8,
                colsample_bytree=0.8,
                reg_lambda=0.5,
                eval_metric="logloss",
                random_state=42
            )
        )
    ]
)

cv_scores = cross_val_score(
    xgb_cv_pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="accuracy",
    n_jobs=-1
)

print("10-Fold Cross Validation Results")
print("=" * 60)

print(
    "Fold scores:",
    np.round(cv_scores, 4)
)

print(
    f"\nMean Accuracy: "
    f"{cv_scores.mean():.4f}"
)

print(
    f"Standard Deviation: "
    f"{cv_scores.std():.4f}"
)

# %%
# ============================================================
# SELECT FINAL MODEL
# ============================================================

final_xgb_pipeline = trained_pipelines[
    "XGBoost"
]

print(
    "XGBoost pipeline selected as final model."
)

# %%
# ============================================================
# XGBOOST VALIDATION PERFORMANCE
# ============================================================

xgb_val_pred = final_xgb_pipeline.predict(
    X_val
)

xgb_val_prob = final_xgb_pipeline.predict_proba(
    X_val
)[:, 1]

print("=" * 60)
print("XGBOOST VALIDATION RESULTS")
print("=" * 60)

print(
    f"Accuracy : "
    f"{accuracy_score(y_val, xgb_val_pred):.4f}"
)

print(
    f"Precision: "
    f"{precision_score(y_val, xgb_val_pred, zero_division=0):.4f}"
)

print(
    f"Recall   : "
    f"{recall_score(y_val, xgb_val_pred, zero_division=0):.4f}"
)

print(
    f"F1 Score : "
    f"{f1_score(y_val, xgb_val_pred, zero_division=0):.4f}"
)

print(
    f"ROC-AUC  : "
    f"{roc_auc_score(y_val, xgb_val_prob):.4f}"
)

# %%
# ============================================================
# XGBOOST THRESHOLD OPTIMIZATION
# ============================================================

precision, recall, thresholds = precision_recall_curve(
    y_val,
    xgb_val_prob
)

# Calculate F1 score for each threshold
f1_scores = (
    2
    * precision[:-1]
    * recall[:-1]
    /
    (
        precision[:-1]
        + recall[:-1]
        + 1e-12
    )
)

best_idx = np.argmax(
    f1_scores
)

best_threshold = thresholds[
    best_idx
]

best_validation_f1 = f1_scores[
    best_idx
]

print(
    f"Best threshold: "
    f"{best_threshold:.4f}"
)

print(
    f"Best validation F1: "
    f"{best_validation_f1:.4f}"
)

# %%
# ============================================================
# FINAL TEST SET EVALUATION
# ============================================================

# Test probabilities
xgb_test_prob = final_xgb_pipeline.predict_proba(
    X_test
)[:, 1]

# Apply optimized threshold
xgb_test_pred = (
    xgb_test_prob >= best_threshold
).astype(int)

# Metrics
test_accuracy = accuracy_score(
    y_test,
    xgb_test_pred
)

test_precision = precision_score(
    y_test,
    xgb_test_pred,
    zero_division=0
)

test_recall = recall_score(
    y_test,
    xgb_test_pred,
    zero_division=0
)

test_f1 = f1_score(
    y_test,
    xgb_test_pred,
    zero_division=0
)

test_roc_auc = roc_auc_score(
    y_test,
    xgb_test_prob
)

print("=" * 70)
print("FINAL XGBOOST TEST RESULTS")
print("=" * 70)

print(
    f"Accuracy : {test_accuracy:.4f}"
)

print(
    f"Precision: {test_precision:.4f}"
)

print(
    f"Recall   : {test_recall:.4f}"
)

print(
    f"F1 Score : {test_f1:.4f}"
)

print(
    f"ROC-AUC  : {test_roc_auc:.4f}"
)

# %%
# ============================================================
# CLASSIFICATION REPORT
# ============================================================

print(
    classification_report(
        y_test,
        xgb_test_pred,
        target_names=[
            "Not On Time",
            "On Time"
        ],
        zero_division=0
    )
)

# %%
# ============================================================
# CONFUSION MATRIX
# ============================================================

cm = confusion_matrix(
    y_test,
    xgb_test_pred
)

plt.figure(figsize=(7, 6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=[
        "Not On Time",
        "On Time"
    ],
    yticklabels=[
        "Not On Time",
        "On Time"
    ]
)

plt.xlabel(
    "Predicted"
)

plt.ylabel(
    "Actual"
)

plt.title(
    "XGBoost Confusion Matrix"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# ROC CURVE
# ============================================================

fpr, tpr, _ = roc_curve(
    y_test,
    xgb_test_prob
)

roc_auc_value = auc(
    fpr,
    tpr
)

plt.figure(figsize=(7, 6))

plt.plot(
    fpr,
    tpr,
    label=f"XGBoost AUC = {roc_auc_value:.4f}"
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--"
)

plt.xlabel(
    "False Positive Rate"
)

plt.ylabel(
    "True Positive Rate"
)

plt.title(
    "XGBoost ROC Curve"
)

plt.legend(
    loc="lower right"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# PRECISION-RECALL CURVE
# ============================================================

precision_curve, recall_curve, _ = (
    precision_recall_curve(
        y_test,
        xgb_test_prob
    )
)

plt.figure(figsize=(7, 6))

plt.plot(
    recall_curve,
    precision_curve
)

plt.xlabel(
    "Recall"
)

plt.ylabel(
    "Precision"
)

plt.title(
    "XGBoost Precision-Recall Curve"
)

plt.tight_layout()
plt.show()

# %%
# ============================================================
# SAVE FINAL MODEL PIPELINE
# ============================================================

MODEL_FILE = "shipment_xgboost_pipeline.pkl"

THRESHOLD_FILE = "decision_threshold.pkl"

joblib.dump(
    final_xgb_pipeline,
    MODEL_FILE
)

joblib.dump(
    best_threshold,
    THRESHOLD_FILE
)

print(
    f"Model saved as: {MODEL_FILE}"
)

print(
    f"Threshold saved as: {THRESHOLD_FILE}"
)

# %%
# ============================================================
# VERIFY SAVED MODEL
# ============================================================

loaded_model = joblib.load(
    MODEL_FILE
)

loaded_threshold = joblib.load(
    THRESHOLD_FILE
)

loaded_prob = loaded_model.predict_proba(
    X_test
)[:, 1]

loaded_pred = (
    loaded_prob >= loaded_threshold
).astype(int)

loaded_accuracy = accuracy_score(
    y_test,
    loaded_pred
)

loaded_auc = roc_auc_score(
    y_test,
    loaded_prob
)

print("=" * 60)
print("SAVED MODEL VERIFICATION")
print("=" * 60)

print(
    f"Saved Model Accuracy: "
    f"{loaded_accuracy:.4f}"
)

print(
    f"Saved Model ROC-AUC: "
    f"{loaded_auc:.4f}"
)

print("\nModel successfully verified.")

# %%
# ============================================================
# SINGLE SHIPMENT PREDICTION
# ============================================================

# Example shipment
sample_shipment = pd.DataFrame({

    "Warehouse_block": ["F"],

    "Mode_of_Shipment": ["Ship"],

    "Customer_care_calls": [4],

    "Customer_rating": [4],

    "Cost_of_the_Product": [239],

    "Prior_purchases": [3],

    "Product_importance": ["medium"],

    "Gender": ["M"],

    "Discount_offered": [6],

    "Weight_in_gms": [5632]
})

# Feature engineering
sample_shipment["Cost_to_Weight_Ratio"] = (
    sample_shipment["Cost_of_the_Product"]
    /
    sample_shipment["Weight_in_gms"]
    .replace(0, np.nan)
)

# Load model
model = joblib.load(
    "shipment_xgboost_pipeline.pkl"
)

threshold = joblib.load(
    "decision_threshold.pkl"
)

# Probability
probability = model.predict_proba(
    sample_shipment
)[0, 1]

# Prediction
prediction = int(
    probability >= threshold
)

print("=" * 60)
print("SHIPMENT PREDICTION")
print("=" * 60)

print(
    f"Probability of On-Time Delivery: "
    f"{probability * 100:.2f}%"
)

print(
    f"Decision Threshold: "
    f"{threshold:.4f}"
)

if prediction == 1:

    print(
        "\nPrediction: ✅ ON TIME"
    )

else:

    print(
        "\nPrediction: ⚠️ NOT ON TIME"
    )

# %%
# ============================================================
# CHECK MODEL FILES
# ============================================================

print("Current directory:")
print(os.getcwd())

print("\nSaved model files:")

for file in [
    "shipment_xgboost_pipeline.pkl",
    "decision_threshold.pkl"
]:

    if os.path.exists(file):
        print(f"✅ {file}")

    else:
        print(f"❌ {file} NOT FOUND")
